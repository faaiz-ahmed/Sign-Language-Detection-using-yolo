# %%
pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
model = YOLO("yolo11n.pt")

# %%
from ultralytics import YOLO
model = YOLO("yolo11n.pt")
results = model.train(data="data.yaml", epochs=30, imgsz=640, batch=2)
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "F:\Python\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "F:\Python\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "f:\Faaiz work\Sign_language_detection\venv\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "f:\Faaiz work\Sign_language_detection\venv\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
# ...

# %%
from ultralytics import YOLO

model=YOLO('runs/detect/train/weights/best.pt')

metrics=model.val()

print("mAP:",metrics.box.map)
print("mAP50:",metrics.box.map50)
print("mAP75:",metrics.box.map75)
print("Per-class mAP:",metrics.box.maps)
# Out:
# Ultralytics 8.3.233  Python-3.10.0 torch-2.9.1+cpu CPU (AMD Ryzen 5 5500U with Radeon Graphics)
# YOLO11n summary (fused): 100 layers, 2,583,517 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 298.5161.1 MB/s, size: 49.9 KB)
# val: Scanning C:\Users\HP\OneDrive\Desktop\abc\test\labels.cache... 7 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 7/7  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.0it/s 0.5s
#                    all          7          7       0.85          1      0.995      0.839
#                  Hello          1          1      0.775          1      0.995      0.895
#               IloveYou          1          1      0.846          1      0.995      0.697
#                     No          1          1      0.851          1      0.995      0.995
#                 Please          1          1      0.857          1      0.995      0.995
# ...

# %%
from ultralytics import YOLO

model=YOLO('runs/detect/train/weights/best.pt')

for result in model.predict(source=0,show=True,imgsz=640,conf=0.9,stream=True):
    pass
# Out:
# 1/1: 0... Success  (inf frames of shape 640x480 at 30.00 FPS)
#
# 0: 480x640 (no detections), 188.9ms
# 0: 480x640 (no detections), 145.3ms
# 0: 480x640 (no detections), 102.4ms
# 0: 480x640 (no detections), 104.1ms
# 0: 480x640 (no detections), 101.3ms
# 0: 480x640 (no detections), 88.6ms
# 0: 480x640 (no detections), 94.2ms
# 0: 480x640 (no detections), 88.6ms
# 0: 480x640 (no detections), 92.1ms
# 0: 480x640 (no detections), 87.1ms
# 0: 480x640 (no detections), 78.5ms
# 0: 480x640 (no detections), 94.2ms
# 0: 480x640 (no detections), 79.4ms
# 0: 480x640 (no detections), 79.3ms
# 0: 480x640 (no detections), 73.4ms
# 0: 480x640 (no detections), 73.2ms
# 0: 480x640 1 IloveYou, 74.6ms
# 0: 480x640 1 IloveYou, 84.9ms
# 0: 480x640 1 IloveYou, 74.9ms
# 0: 480x640 1 IloveYou, 76.9ms
# 0: 480x640 1 IloveYou, 82.5ms
# 0: 480x640 1 IloveYou, 84.9ms
# 0: 480x640 1 IloveYou, 77.0ms
# 0: 480x640 1 IloveYou, 80.7ms
# 0: 480x640 1 IloveYou, 76.3ms
# 0: 480x640 1 IloveYou, 68.0ms
# ...

# %%
from ultralytics import YOLO

model=YOLO('runs/detect/train/weights/best.pt')

for result in model.predict(source='http://172.18.9.163:8080/video',show=True,imgsz=640,conf=0.5,stream=True):
    pass
# Out:
# 1/1: http://172.18.9.163:8080/video... Success  (inf frames of shape 1920x1080 at 25.00 FPS)
#
# 0: 384x640 (no detections), 78.9ms
# 0: 384x640 (no detections), 102.3ms
# 0: 384x640 (no detections), 78.3ms
# 0: 384x640 (no detections), 89.6ms
# 0: 384x640 (no detections), 76.3ms
# 0: 384x640 (no detections), 77.8ms
# 0: 384x640 (no detections), 75.9ms
# 0: 384x640 (no detections), 76.5ms
# 0: 384x640 (no detections), 77.4ms
# 0: 384x640 (no detections), 79.4ms
# 0: 384x640 (no detections), 70.7ms
# 0: 384x640 (no detections), 63.2ms
# WARNING Waiting for stream 0
# 0: 384x640 (no detections), 62.8ms
# 0: 384x640 (no detections), 61.3ms
# 0: 384x640 (no detections), 63.4ms
# 0: 384x640 (no detections), 65.8ms
# 0: 384x640 (no detections), 95.4ms
# 0: 384x640 1 Yes, 67.2ms
# 0: 384x640 (no detections), 61.3ms
# 0: 384x640 (no detections), 67.3ms
# 0: 384x640 (no detections), 58.9ms
# 0: 384x640 (no detections), 57.8ms
# 0: 384x640 (no detections), 62.1ms
# ...
